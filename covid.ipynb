# %%
import pandas as pd

# %%
data = pd.read_csv("c.csv")

# %%
data = data.drop(columns = ["Unnamed: 0", "Unnamed: 40", "Unnamed: 41"])

# %%
data.continent.value_counts()
# Out:
# Europe           13748
# Asia             12548
# Africa           12482
# North America     8360
# South America     3133
# Oceania           1998
# Name: continent, dtype: int64

# %%
cont = data.groupby(by="continent")

# %%
cont.plot.hist(x="continent", y="month")
# Out:
# continent
# Africa           AxesSubplot(0.125,0.125;0.775x0.755)
# Asia             AxesSubplot(0.125,0.125;0.775x0.755)
# Europe           AxesSubplot(0.125,0.125;0.775x0.755)
# North America    AxesSubplot(0.125,0.125;0.775x0.755)
# Oceania          AxesSubplot(0.125,0.125;0.775x0.755)
# South America    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
NA1 = NA[NA["month"]==1]
SA1 = SA[SA["month"]==1]
A1 = A[A["month"]==1]
AF1 = AF[AF["month"]==1]
EU1 = EU[EU["month"]==1]
OC1 = OC[OC["month"]==1]

# %%
OC1.count()
# Out:
# date                               64
# continent                          64
# location                           64
# total_cases                        64
# new_cases                          64
# new_cases_smoothed                 64
# total_deaths                       64
# new_deaths                         64
# new_deaths_smoothed                64
# total_cases_per_million            64
# new_cases_per_million              64
# new_cases_smoothed_per_million     64
# total_deaths_per_million           64
# new_deaths_per_million             64
# new_deaths_smoothed_per_million    64
# total_tests                        64
# new_tests                          64
# total_tests_per_thousand           64
# new_tests_per_thousand             64
# new_tests_smoothed                 64
# new_tests_smoothed_per_thousand    64
# tests_per_case                     64
# positive_rate                      64
# tests_units                        64
# stringency_index                   64
# ...
